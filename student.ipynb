# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/kc_house_data.csv")
df.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
# ...

# %%
f=open("data/column_names.md", 'r')
column_names=[]
col_names={}

for i in f:
  column_names.append(i.split("-"))

column_names
cn=pd.DataFrame(column_names)

cn.drop(index=[0,10,12,14,16],axis=0, inplace=True)

cn.columns=["column_name", "column_description"]

cn
# Out:
#            column_name                                 column_description
# 1              * `id`                     Unique identifier for a house\n
# 2            * `date`                               Date house was sold\n
# 3           * `price`                    Sale price (prediction target)\n
# 4        * `bedrooms`                                Number of bedrooms\n
# 5       * `bathrooms`                               Number of bathrooms\n
# 6     * `sqft_living`        Square footage of living space in the home\n
# 7        * `sqft_lot`                         Square footage of the lot\n
# 8          * `floors`                Number of floors (levels) in house\n
# 9      * `waterfront`              Whether the house is on a waterfront\n
# 11           * `view`                        Quality of view from house\n
# 13      * `condition`    How good the overall condition of the house i...
# 15          * `grade`    Overall grade of the house. Related to the co...
# ...

# %%
cn['column_name']=cn['column_name'].map(lambda x:x.lstrip('*'))
cn.iloc[:,[0,1]]
# Out:
#           column_name                                 column_description
# 1               `id`                     Unique identifier for a house\n
# 2             `date`                               Date house was sold\n
# 3            `price`                    Sale price (prediction target)\n
# 4         `bedrooms`                                Number of bedrooms\n
# 5        `bathrooms`                               Number of bathrooms\n
# 6      `sqft_living`        Square footage of living space in the home\n
# 7         `sqft_lot`                         Square footage of the lot\n
# 8           `floors`                Number of floors (levels) in house\n
# 9       `waterfront`              Whether the house is on a waterfront\n
# 11            `view`                        Quality of view from house\n
# 13       `condition`    How good the overall condition of the house i...
# 15           `grade`    Overall grade of the house. Related to the co...
# ...

# %%
df.iloc[:,[3,4]]
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# ...         ...        ...
# 21592         3       2.50
# 21593         4       2.50
# 21594         2       0.75
# 21595         3       2.50
# 21596         2       0.75
#
# [21597 rows x 2 columns]

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# ...

# %%
df[['grade','condition']]
# Out:
#                grade  condition
# 0          7 Average    Average
# 1          7 Average    Average
# 2      6 Low Average    Average
# 3          7 Average  Very Good
# 4             8 Good    Average
# ...              ...        ...
# 21592         8 Good    Average
# 21593         8 Good    Average
# 21594      7 Average    Average
# 21595         8 Good    Average
# 21596      7 Average    Average
#
# [21597 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.isnull().any(axis=0)
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront        True
# view              True
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated      True
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
wf=df['waterfront']
wf.head(20)
# Out:
# 0     NaN
# 1      NO
# 2      NO
# 3      NO
# 4      NO
# 5      NO
# 6      NO
# 7      NO
# 8      NO
# 9      NO
# 10    NaN
# 11     NO
# 12     NO
# 13     NO
# 14     NO
# 15     NO
# 16     NO
# 17     NO
# 18     NO
# 19     NO
# Name: waterfront, dtype: object

# %%
df["waterfront"].fillna("", inplace = True)

# %%
null_wf=df[df['waterfront']!= 'NO' ]
# df['waterfront']='No'
null_wf
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 10     1736800520    4/3/2015   662500.0         3       2.50         3560
# 23     8091400200   5/16/2014   252700.0         2       1.50         1070
# 40     5547700270   7/15/2014   625000.0         4       2.50         2570
# 49      822039084   3/11/2015  1350000.0         3       2.50         2753
# ...           ...         ...        ...       ...        ...          ...
# 21578  5087900040  10/17/2014   350000.0         4       2.75         2500
# 21582  8956200760  10/13/2014   541800.0         4       2.50         3118
# 21586   844000965   6/26/2014   224000.0         3       1.75         1500
# 21587  7852140040   8/25/2014   507250.0         3       2.50         2270
# 21595   291310100   1/16/2015   400000.0         3       2.50         1600
#
# ...

# %%
conditions = [
    (df['waterfront'] == 'nan' ),
    (df['waterfront'] =='NO'),
    (df['waterfront'] == 'YES')
]

values = [0, 0, 1]

df['waterfront_code'] = np.select(conditions, values)
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ... sqft_above sqft_basement  \
# ...

# %%
df.waterfront.unique()
# Out:
# array(['', 'NO', 'YES'], dtype=object)

# %%
df.waterfront_code.unique()
# Out:
# array([0, 1])

# %%
df.view.unique()
# Out:
# array(['NONE', nan, 'GOOD', 'EXCELLENT', 'AVERAGE', 'FAIR'], dtype=object)

# %%
df.condition.unique()
# Out:
# array(['Average', 'Very Good', 'Good', 'Poor', 'Fair'], dtype=object)

# %%
conditions = [
    (df['condition'] == 'Poor'),
    (df['condition'] == 'Fair'),
    (df['condition'] == 'Average' ),
    (df['condition'] == 'Good'),
    (df['condition'] =='Very Good')
]

values = [1,2,3,4,5]

df['condition_code'] = np.select(conditions, values)
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ... sqft_basement yr_built  \
# ...

# %%
df_lessnas=df.dropna()
df_lessnas
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# ...           ...         ...        ...       ...        ...          ...
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21595   291310100   1/16/2015   400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
# ...
